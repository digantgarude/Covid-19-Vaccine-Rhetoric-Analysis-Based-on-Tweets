# %%
import pandas as pd

import gensim
from sklearn.feature_extraction.text import CountVectorizer

# %%
poi_names = ['CDCgov', 'JoeBiden', 'GovRonDeSantis', 'tedcruz', 'RandPaul', 'MoHFW_INDIA', 'narendramodi', 'ArvindKejriwal', 'sambitswaraj', 'MamataOfficial', 'SSalud_mx', 'lopezobrador_', 'alitomorenoc', 'VicenteFoxQue', 'fernandeznorona', 'RicardoMonrealA', 'BernieSanders', 'KamalaHarris', 'PeteButtigieg', 'GregAbbott_TX', 'LindseyGrahamSC', 'mattgaetz', 'marcorubio', 'mtgreenee', 'SecBecerra', 'mansukhmandviya']

# %%
CORE_NAME_FETCH = "IRF21P1"
CORE_NAME_UPLOAD = "BF_Project4"
# AWS_IP_FETCH = "3.141.19.45"
AWS_IP_FETCH = "18.216.184.141"
AWS_IP_UPLOAD = "3.21.230.103"

from solr_connect import SolrConnect

sc = SolrConnect()

sc.connect(CORE_NAME_FETCH, AWS_IP_FETCH)

tweets = sc.get_tweets()

len(tweets)
# Out:
# 97389

# %%
tweets[0]
# Out:
# {'verified': False,
#  'country': 'USA',
#  'id': '1440485662189240320',
#  'replied_to_tweet_id': 1440484592775925760,
#  'replied_to_user_id': 1309563283196858368,
#  'reply_text': 'I know that face Kelly &amp; Diggle just made. Everybody DOESNT win. Besides Kelly, did they even check on the people in the hospital????!?',
#  'tweet_text': 'I know that face Kelly &amp; Diggle just made. Everybody DOESN’T win. Besides Kelly, did they even check on the people in the hospital????!? #Supergirl',
#  'tweet_lang': 'en',
#  'text_en': 'I know that face Kelly &amp; Diggle just made. Everybody DOESNT win. Besides Kelly, did they even check on the people in the hospital????!?',
#  'hashtags': ['Supergirl'],
#  'tweet_date': '2021-09-22T01:00:00Z',
#  '_version_': 1711654113153908736}

# %%
invalid_lang_tweets = []
for data in tweets:
    if "tweet_lang" not in data.keys():
        invalid_lang_tweets.append(data)

# %%
len(invalid_lang_tweets)
# Out:
# 0

# %%
poi_tweets = [
        {
            "id": 1,
            "screen_name": "CDCgov",
            "country": "USA",
            "count": 1000,
            "finished": 1,
            "reply_finished": 1,
            "collected": 1000,
            "reply_count": 1000
        },
        {
            "id": 2,
            "screen_name": "JoeBiden",
            "country": "USA",
            "count": 1000,
            "finished": 1,
            "reply_finished": 1,
            "collected": 520,
            "reply_count": 2000
        },
        {
            "id": 3,
            "screen_name": "GovRonDeSantis",
            "country": "USA",
            "count": 1000,
            "finished": 1,
            "reply_finished": 1,
            "collected": 1000,
            "reply_count": 3000
        },
        {
            "id": 4,
            "screen_name": "tedcruz",
            "country": "USA",
            "count": 1000,
            "finished": 1,
            "reply_finished": 1,
            "collected": 1000,
            "reply_count": 4000
        },
        {
            "id": 5,
            "screen_name": "RandPaul",
            "country": "USA",
            "count": 1000,
            "finished": 1,
            "reply_finished": 1,
            "collected": 1000,
            "reply_count": 5000
        },
        {
            "id": 6,
            "screen_name": "MoHFW_INDIA",
            "country": "INDIA",
            "count": 1000,
            "finished": 1,
            "reply_finished": 1,
            "collected": 940,
            "reply_count": 6000
        },
        {
            "id": 7,
            "screen_name": "narendramodi",
            "country": "INDIA",
            "count": 1000,
            "finished": 1,
            "reply_finished": 1,
            "collected": 1000,
            "reply_count": 7000
        },
        {
            "id": 8,
            "screen_name": "ArvindKejriwal",
            "country": "INDIA",
            "count": 1000,
            "finished": 1,
            "reply_finished": 1,
            "collected": 1000,
            "reply_count": 7615
        },
        {
            "id": 9,
            "screen_name": "sambitswaraj",
            "country": "INDIA",
            "count": 1000,
            "finished": 1,
            "reply_finished": 1,
            "collected": 1000,
            "reply_count": 7661
        },
        {
            "id": 10,
            "screen_name": "MamataOfficial",
            "country": "INDIA",
            "count": 1000,
            "finished": 1,
            "reply_finished": 1,
            "collected": 1000,
            "reply_count": 7776
        },
        {
            "id": 11,
            "screen_name": "SSalud_mx",
            "country": "MEXICO",
            "count": 1000,
            "finished": 1,
            "reply_finished": 1,
            "collected": 1000,
            "reply_count": 8776
        },
        {
            "id": 12,
            "screen_name": "lopezobrador_",
            "country": "MEXICO",
            "count": 1000,
            "finished": 1,
            "reply_finished": 1,
            "collected": 1000,
            "reply_count": 9776
        },
        {
            "id": 13,
            "screen_name": "alitomorenoc",
            "country": "MEXICO",
            "count": 1000,
            "finished": 1,
            "reply_finished": 1,
            "collected": 1000,
            "reply_count": 9786
        },
        {
            "id": 14,
            "screen_name": "VicenteFoxQue",
            "country": "MEXICO",
            "count": 1000,
            "finished": 1,
            "reply_finished": 1,
            "collected": 1000,
            "reply_count": 9801
        },
        {
            "id": 15,
            "screen_name": "fernandeznorona",
            "country": "MEXICO",
            "count": 1000,
            "finished": 1,
            "reply_finished": 1,
            "collected": 1000,
            "reply_count": 9821
        },
        {
            "id": 16,
            "screen_name": "RicardoMonrealA",
            "country": "MEXICO",
            "count": 1000,
            "finished": 1,
            "reply_finished": 1,
            "collected": 1000,
            "reply_count": 9827
        },
        {
            "id": 17,
            "screen_name": "BernieSanders",
            "country": "USA",
            "count": 1000,
            "finished": 1,
            "reply_finished": 1,
            "collected": 1000,
            "reply_count": 10203
        },
        {
            "id": 17,
            "screen_name": "KamalaHarris",
            "country": "USA",
            "count": 1000,
            "finished": 1,
            "reply_finished": 1,
            "collected": 1000,
            "reply_count": 10805
        },
        {
            "id": 18,
            "screen_name": "PeteButtigieg",
            "country": "USA",
            "count": 1000,
            "finished": 1,
            "reply_finished": 1,
            "collected": 1000,
            "reply_count": 10835
        },
        {
            "id": 19,
            "screen_name": "GregAbbott_TX",
            "country": "USA",
            "count": 1000,
            "finished": 1,
            "reply_finished": 1,
            "collected": 1000,
            "reply_count": 11835
        },
        {
            "id": 20,
            "screen_name": "LindseyGrahamSC",
            "country": "USA",
            "count": 1000,
            "finished": 1,
            "reply_finished": 1,
            "collected": 1000,
            "reply_count": 12000
        },
        {
            "id": 21,
            "screen_name": "mattgaetz",
            "country": "USA",
            "count": 1000,
            "finished": 1,
            "reply_finished": 1,
            "collected": 1000,
            "reply_count": 12078
        },
        {
            "id": 22,
            "screen_name": "marcorubio",
            "country": "USA",
            "count": 1000,
            "finished": 1,
            "reply_finished": 1,
            "collected": 1000,
            "reply_count": 12613
        },
        {
            "id": 23,
            "screen_name": "mtgreenee",
            "country": "USA",
            "count": 1000,
            "finished": 1,
            "reply_finished": 1,
            "collected": 1000,
            "reply_count": 13613
        },
        {
            "id": 24,
            "screen_name": "SecBecerra",
            "country": "USA",
            "count": 3000,
            "finished": 1,
            "reply_finished": 1,
            "collected": 383,
            "reply_count": 13670
        },
        {
            "id": 25,
            "screen_name": "mansukhmandviya",
            "country": "INDIA",
            "count": 3000,
            "finished": 1,
            "reply_finished": 1,
            "collected": 3000,
            "reply_count": 14398
        }
    ]

# %%
poi_names = [poi["screen_name"] for poi in poi_tweets]

# %%
def convert_to_df_for_lda(tweets):
    filter_only_english =[]
    for data in tweets:
        if data['tweet_lang'] == "en" and 'text_en' in data.keys():
            filter_only_english.append(data)
    tweets_data = [[data['id'], data['text_en']] for data in filter_only_english]


    df = pd.DataFrame(tweets_data, columns=["id","text_en"])
    return df

df = convert_to_df_for_lda(tweets)

# %%
def train_lda_model(passes=10,iterations=10,num_topics=10, transform_text= None):
    # Use CountVectorizor to find three letter tokens, remove stop_words, 
    # remove tokens that don't appear in at least 20 documents,
    # remove tokens that appear in more than 20% of the documents
    vect = CountVectorizer(min_df=20, max_df=0.2, stop_words='english', 
                        token_pattern='(?u)\\b\\w\\w\\w+\\b')
    # Fit and transform
    X = vect.fit_transform(transform_text)
    
    # Convert sparse matrix to gensim corpus.
    corpus = gensim.matutils.Sparse2Corpus(X, documents_columns=False)
    
    # Mapping from word IDs to words (To be used in LdaModel's id2word parameter)
    id_map = dict((v, k) for k, v in vect.vocabulary_.items())
    
    
    # Use the gensim.models.ldamodel.LdaModel constructor to estimate 
    # LDA model parameters on the corpus, and save to the variable `ldamodel`

    ldamodel = gensim.models.LdaMulticore(corpus=corpus, id2word=id_map, passes=passes,iterations=iterations,
                                                random_state=5, num_topics=num_topics, workers=4)
    return ldamodel
ldamodel = train_lda_model(num_topics=10, passes=10, iterations=5, transform_text=df.text_en)

# %%
def print_topics(ldamodel):
    for idx, topic in ldamodel.print_topics(num_words=10):
        print("Topic: {} \nWords: {}".format(idx, topic))
        print("\n")

print_topics(ldamodel)
# Out:
# Topic: 0
# Words: 0.023*"johnson" + 0.015*"new" + 0.014*"virus" + 0.011*"general" + 0.010*"china" + 0.010*"super" + 0.010*"weeks" + 0.010*"said" + 0.009*"true" + 0.009*"wuhan"
#
#
# Topic: 1
# Words: 0.035*"got" + 0.023*"day" + 0.022*"dose" + 0.017*"shot" + 0.017*"days" + 0.016*"second" + 0.015*"positive" + 0.012*"stay" + 0.012*"tested" + 0.011*"amp"
#
#
# Topic: 2
# Words: 0.028*"people" + 0.026*"like" + 0.022*"just" + 0.013*"know" + 0.012*"don" + 0.012*"think" + 0.010*"want" + 0.010*"vaccinated" + 0.010*"right" + 0.008*"mask"
#
#
# Topic: 3
# Words: 0.057*"vaccine" + 0.035*"vaccinated" + 0.031*"vaccines" + 0.028*"booster" + 0.024*"fully" + 0.021*"pfizer" + 0.018*"people" + 0.014*"antibodies" + 0.014*"immunity" + 0.013*"amp"
#
#
# Topic: 4
# Words: 0.037*"cases" + 0.036*"deaths" + 0.027*"new" + 0.018*"death" + 0.014*"anti" + 0.013*"variant" + 0.013*"patients" + 0.013*"died" + 0.012*"delta" + 0.012*"rate"
#
#
# Topic: 5
# ...

# %%
lda_topics = ldamodel.get_topics()

# %%
from gensim.test.utils import datapath


temp_file = datapath("./model.bin")

ldamodel.save(temp_file)

# %% [markdown]
# # FOR POI NAMES :

# %%
poi_name = "CDCgov"

poi_tweets = sc.get_tweets(query_params=f"poi_name:{poi_name}", no_of_rows=1000000)

# %%
df_poi = convert_to_df_for_lda(poi_tweets)
ldamodel_poi = train_lda_model(num_topics=10, passes=10, iterations=5, transform_text=df_poi.text_en)
print_topics(ldamodel_poi)
# Out:
# Topic: 0
# Words: 0.194*"amp" + 0.079*"children" + 0.065*"spread" + 0.059*"mask" + 0.051*"water" + 0.046*"help" + 0.043*"wear" + 0.037*"areas" + 0.037*"protect" + 0.034*"staff"
#
#
# Topic: 1
# Words: 0.107*"vaccine" + 0.079*"dose" + 0.074*"stay" + 0.070*"use" + 0.070*"pandemic" + 0.061*"fully" + 0.058*"people" + 0.057*"million" + 0.053*"received" + 0.034*"cdc"
#
#
# Topic: 2
# Words: 0.103*"read" + 0.073*"update" + 0.072*"variants" + 0.068*"delta" + 0.058*"variant" + 0.052*"virus" + 0.051*"states" + 0.047*"united" + 0.043*"latest" + 0.043*"causes"
#
#
# Topic: 3
# Words: 0.125*"health" + 0.093*"vaccine" + 0.065*"vaccines" + 0.044*"cdc" + 0.040*"amp" + 0.034*"vaccination" + 0.029*"older" + 0.029*"near" + 0.029*"healthcare" + 0.027*"years"
#
#
# Topic: 4
# Words: 0.102*"national" + 0.090*"reported" + 0.089*"likely" + 0.078*"predict" + 0.077*"forecasts" + 0.075*"deaths" + 0.060*"ending" + 0.058*"week" + 0.053*"august" + 0.052*"july"
#
#
# Topic: 5
# ...
