# %%
import pandas as pd

import gensim
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd
import re

# %%
CORE_NAME_FETCH = "IR_P4"

AWS_IP_FETCH = "3.21.230.103"
# AWS_IP_FETCH = "3.141.19.45"
#AWS_IP_FETCH = "18.216.184.141"
#AWS_IP_UPLOAD = "3.21.230.103"

from solr_connect import SolrConnect

sc = SolrConnect()

sc.connect(CORE_NAME_FETCH, AWS_IP_FETCH)

#tweets = sc.get_tweets(query_params='tweet_text:covid')

#len(tweets)

# %%
poi_all = [
        {
            "id": 1,
            "screen_name": "CDCgov",
            "country": "USA",
            "count": 1000,
            "finished": 1,
            "reply_finished": 1,
            "collected": 1000,
            "reply_count": 1000
        },
        {
            "id": 2,
            "screen_name": "JoeBiden",
            "country": "USA",
            "count": 1000,
            "finished": 1,
            "reply_finished": 1,
            "collected": 520,
            "reply_count": 2000
        },
        {
            "id": 3,
            "screen_name": "GovRonDeSantis",
            "country": "USA",
            "count": 1000,
            "finished": 1,
            "reply_finished": 1,
            "collected": 1000,
            "reply_count": 3000
        },
        {
            "id": 4,
            "screen_name": "tedcruz",
            "country": "USA",
            "count": 1000,
            "finished": 1,
            "reply_finished": 1,
            "collected": 1000,
            "reply_count": 4000
        },
        {
            "id": 5,
            "screen_name": "RandPaul",
            "country": "USA",
            "count": 1000,
            "finished": 1,
            "reply_finished": 1,
            "collected": 1000,
            "reply_count": 5000
        },
        {
            "id": 6,
            "screen_name": "MoHFW_INDIA",
            "country": "INDIA",
            "count": 1000,
            "finished": 1,
            "reply_finished": 1,
            "collected": 940,
            "reply_count": 6000
        },
        {
            "id": 7,
            "screen_name": "narendramodi",
            "country": "INDIA",
            "count": 1000,
            "finished": 1,
            "reply_finished": 1,
            "collected": 1000,
            "reply_count": 7000
        },
        {
            "id": 8,
            "screen_name": "ArvindKejriwal",
            "country": "INDIA",
            "count": 1000,
            "finished": 1,
            "reply_finished": 1,
            "collected": 1000,
            "reply_count": 7615
        },
        {
            "id": 9,
            "screen_name": "sambitswaraj",
            "country": "INDIA",
            "count": 1000,
            "finished": 1,
            "reply_finished": 1,
            "collected": 1000,
            "reply_count": 7661
        },
        {
            "id": 10,
            "screen_name": "MamataOfficial",
            "country": "INDIA",
            "count": 1000,
            "finished": 1,
            "reply_finished": 1,
            "collected": 1000,
            "reply_count": 7776
        },
        {
            "id": 11,
            "screen_name": "SSalud_mx",
            "country": "MEXICO",
            "count": 1000,
            "finished": 1,
            "reply_finished": 1,
            "collected": 1000,
            "reply_count": 8776
        },
        {
            "id": 12,
            "screen_name": "lopezobrador_",
            "country": "MEXICO",
            "count": 1000,
            "finished": 1,
            "reply_finished": 1,
            "collected": 1000,
            "reply_count": 9776
        },
        {
            "id": 13,
            "screen_name": "alitomorenoc",
            "country": "MEXICO",
            "count": 1000,
            "finished": 1,
            "reply_finished": 1,
            "collected": 1000,
            "reply_count": 9786
        },
        {
            "id": 14,
            "screen_name": "VicenteFoxQue",
            "country": "MEXICO",
            "count": 1000,
            "finished": 1,
            "reply_finished": 1,
            "collected": 1000,
            "reply_count": 9801
        },
        {
            "id": 15,
            "screen_name": "fernandeznorona",
            "country": "MEXICO",
            "count": 1000,
            "finished": 1,
            "reply_finished": 1,
            "collected": 1000,
            "reply_count": 9821
        },
        {
            "id": 16,
            "screen_name": "RicardoMonrealA",
            "country": "MEXICO",
            "count": 1000,
            "finished": 1,
            "reply_finished": 1,
            "collected": 1000,
            "reply_count": 9827
        },
        {
            "id": 17,
            "screen_name": "BernieSanders",
            "country": "USA",
            "count": 1000,
            "finished": 1,
            "reply_finished": 1,
            "collected": 1000,
            "reply_count": 10203
        },
        {
            "id": 17,
            "screen_name": "KamalaHarris",
            "country": "USA",
            "count": 1000,
            "finished": 1,
            "reply_finished": 1,
            "collected": 1000,
            "reply_count": 10805
        },
        {
            "id": 18,
            "screen_name": "PeteButtigieg",
            "country": "USA",
            "count": 1000,
            "finished": 1,
            "reply_finished": 1,
            "collected": 1000,
            "reply_count": 10835
        },
        {
            "id": 19,
            "screen_name": "GregAbbott_TX",
            "country": "USA",
            "count": 1000,
            "finished": 1,
            "reply_finished": 1,
            "collected": 1000,
            "reply_count": 11835
        },
        {
            "id": 20,
            "screen_name": "LindseyGrahamSC",
            "country": "USA",
            "count": 1000,
            "finished": 1,
            "reply_finished": 1,
            "collected": 1000,
            "reply_count": 12000
        },
        {
            "id": 21,
            "screen_name": "mattgaetz",
            "country": "USA",
            "count": 1000,
            "finished": 1,
            "reply_finished": 1,
            "collected": 1000,
            "reply_count": 12078
        },
        {
            "id": 22,
            "screen_name": "marcorubio",
            "country": "USA",
            "count": 1000,
            "finished": 1,
            "reply_finished": 1,
            "collected": 1000,
            "reply_count": 12613
        },
        {
            "id": 23,
            "screen_name": "mtgreenee",
            "country": "USA",
            "count": 1000,
            "finished": 1,
            "reply_finished": 1,
            "collected": 1000,
            "reply_count": 13613
        },
        {
            "id": 24,
            "screen_name": "SecBecerra",
            "country": "USA",
            "count": 3000,
            "finished": 1,
            "reply_finished": 1,
            "collected": 383,
            "reply_count": 13670
        },
        {
            "id": 25,
            "screen_name": "mansukhmandviya",
            "country": "INDIA",
            "count": 3000,
            "finished": 1,
            "reply_finished": 1,
            "collected": 3000,
            "reply_count": 14398
        }
    ]

# %%
def convert_to_df_for_lda(tweets):
    filter_only_english =[]
    for data in tweets:
        if data['tweet_lang'] == "en" and 'text_en' in data.keys():
            filter_only_english.append(data)
    tweets_data = [[data['id'], data['text_en']] for data in filter_only_english]
    if(len(tweets_data))==0:
        return pd.DataFrame()
        

    df = pd.DataFrame(tweets_data, columns=["id","text_en"])
    return df

# %%
def train_lda_model(passes=10,iterations=10,num_topics=10, transform_text= None):
    # Use CountVectorizor to find three letter tokens, remove stop_words, 
    # remove tokens that don't appear in at least 20 documents,
    # remove tokens that appear in more than 20% of the documents
    
    vect = CountVectorizer(min_df=0, max_df=0.5, stop_words='english', 
                        token_pattern='(?u)\\b\\w\\w\\w+\\b')
    # Fit and transform

    X = vect.fit_transform(transform_text)
    

    # Convert sparse matrix to gensim corpus.
    corpus = gensim.matutils.Sparse2Corpus(X, documents_columns=False)
    
    # Mapping from word IDs to words (To be used in LdaModel's id2word parameter)
    id_map = dict((v, k) for k, v in vect.vocabulary_.items())
    
    
    # Use the gensim.models.ldamodel.LdaModel constructor to estimate 
    # LDA model parameters on the corpus, and save to the variable `ldamodel`

    ldamodel = gensim.models.LdaMulticore(corpus=corpus, id2word=id_map, passes=passes,iterations=iterations,
                                                random_state=5, num_topics=num_topics, workers=4)
    return ldamodel
#ldamodel = train_lda_model(num_topics=5, passes=10, iterations=5, transform_text=df.text_en)

# %%
#Evaluate LDA for each POI

poi_topics={}

for poi in poi_all:
    word = []
    poi_name = poi['screen_name']
    if(poi_name == 'MamataOfficial'):
        continue
    poi_tweets = sc.get_tweets(query_params=f"poi_name:{poi_name}", no_of_rows=1000000)
    df_poi = convert_to_df_for_lda(poi_tweets)
    if(len(df_poi) <=200):
        continue
    print(len(df_poi), poi_name)
    ldamodel_poi = train_lda_model(num_topics=10, passes=10, iterations=50, transform_text=df_poi.text_en)
    for i in range(len(ldamodel_poi.print_topics())):
        word.append(re.sub(r"[^a-zA-Z0-9]","",ldamodel_poi.print_topics()[i][1].split('+')[0].split('*')[1]))
    poi_topics[poi_name] = word
    print(poi_name)
# Out:
# 731 CDCgov
# CDCgov
# 863 JoeBiden
# JoeBiden
# 928 tedcruz
# tedcruz
# 532 RandPaul
# RandPaul
# 783 MoHFW_INDIA
# MoHFW_INDIA
# 439 narendramodi
# narendramodi
# 372 ArvindKejriwal
# ArvindKejriwal
# 495 sambitswaraj
# sambitswaraj
# 1396 BernieSanders
# BernieSanders
# 889 KamalaHarris
# KamalaHarris
# 297 PeteButtigieg
# PeteButtigieg
# 262 GregAbbott_TX
# GregAbbott_TX
# 317 LindseyGrahamSC
# LindseyGrahamSC
# 712 mattgaetz
# mattgaetz
# 677 mtgreenee
# mtgreenee
# 810 mansukhmandviya
# mansukhmandviya

# %%
poi_topics
# Out:
# {'CDCgov': ['learn',
#   'new',
#   'covid',
#   'new',
#   'vaccinated',
#   'amp',
#   'covid',
#   'help',
#   'health',
#   'amp'],
#  'JoeBiden': ['american',
#   'president',
#   'vote',
#   'president',
#   'president',
#   'day',
#   'president',
#   'build',
#   'election',
#   'trump'],
#  'tedcruz': ['biden',
#   'amp',
#   'biden',
#   'biden',
#   'biden',
#   'cruz',
#   'biden',
#   'amp',
#   'biden',
#   'people'],
#  'RandPaul': ['free',
#   'sen',
#   'senate',
#   'science',
#   'sen',
#   'paul',
#   'senator',
#   'people',
#   'senate',
#   'congress'],
#  'MoHFW_INDIA': ['vaccination',
#   'india',
#   'covid',
#   'amp',
#   'vaccine',
#   'vaccination',
#   'mis',
#   'samples',
#   'crore',
#   'cases'],
#  'narendramodi': ['india',
#   'demise',
#   'bengal',
#   'occasion',
#   'women',
#   'party',
#   'covid',
#   'people',
#   'covid',
#   'india'],
#  'ArvindKejriwal': ['delhi',
#   'delhi',
#   'congratulations',
#   'goa',
#   'delhi',
#   'delhi',
#   'vaccination',
#   'god',
#   'delhi',
#   'delhi'],
#  'sambitswaraj': ['shri',
#   'president',
#   'congratulations',
#   'amp',
#   'india',
#   'shri',
#   'birthday',
#   'amp',
#   'amp',
#   'constituency'],
#  'BernieSanders': ['new',
#   'medicare',
#   'vote',
#   'people',
#   'big',
#   'working',
#   'people',
#   'join',
#   'working',
#   'trump'],
#  'KamalaHarris': ['today',
#   'mask',
#   'people',
#   'vote',
#   'country',
#   'president',
#   'care',
#   'vote',
#   'trump',
#   'tune'],
#  'PeteButtigieg': ['time',
#   'people',
#   'amp',
#   'news',
#   'president',
#   'people',
#   'trump',
#   'infrastructure',
#   'today',
#   'years'],
#  'GregAbbott_TX': ['amp',
#   'covid',
#   'power',
#   'amp',
#   'amp',
#   'state',
#   'amp',
#   'trafficking',
#   'shot',
#   'amp'],
#  'LindseyGrahamSC': ['trump',
#   'president',
#   'president',
#   'president',
#   'senate',
#   'graham',
#   'president',
#   'president',
#   'senator',
#   'speaking'],
#  'mattgaetz': ['gaetz',
#   'need',
#   'join',
#   'gaetz',
#   'critical',
#   'gaetz',
#   'amp',
#   'gaetz',
#   'america',
#   'gaetz'],
#  'mtgreenee': ['people',
#   'people',
#   'biden',
#   'amp',
#   'amp',
#   'biden',
#   'amp',
#   'rally',
#   'amp',
#   'people'],
#  'mansukhmandviya': ['shri',
#   'amp',
#   'india',
#   'shri',
#   'shri',
#   'shri',
#   'covid',
#   'india',
#   'shri',
#   'india']}

# %%
import json
with open('poi_topics.json', 'w') as f:
    json.dump(poi_topics, f,indent=4)
